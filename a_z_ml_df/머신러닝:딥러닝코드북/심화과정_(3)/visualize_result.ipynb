# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.optimizers import Adam
from model.segmentation import UNet
from util.function import *
from util.metric import *
from util.plot import *
def main():
    data_path = './traindata/' #train and validation data path
    prediction_result_path='./prediction_result.npy' #prediction result file path
    sample_number=20 #set the number of sample data want to visualize
    #load validation data and segmentation result
    imgs_valid = np.load(data_path+"valid_image.npy").astype(np.float32)
    imgs_mask_valid = np.load(data_path+"valid_mask.npy").astype(np.float32)
    imgs_mask_predict = np.load(prediction_result_path).astype(np.float32)
    #post processing
    imgs_mask_predict[imgs_mask_predict>0.5]=1
    imgs_mask_predict[imgs_mask_predict<=0.5]=0
    #visualize mask, segmentation
    print("-"*50)
    print("visualize mask")
    print("-"*50)
    show_mask(imgs_valid,imgs_mask_valid,imgs_mask_predict,sample_number)
    print("-"*50)
    print("visualize segmentation")
    print("-"*50)
    show_segmentation(imgs_valid,imgs_mask_valid,imgs_mask_predict,sample_number)
    
if __name__ == "__main__":
    main()
# Out:
# --------------------------------------------------
# visualize mask
# --------------------------------------------------
# --------------------------------------------------
# visualize segmentation
# --------------------------------------------------
